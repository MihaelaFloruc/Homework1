# %% [markdown]
# <a href="https://colab.research.google.com/github/MihaelaFloruc/Homework1/blob/main/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En el següent codi el que he fet és resoldre dues equacions diferencials per unes condicions inicials en concret de forma gràfica. Per això, en primer pas he definit la funció de la manera específica que et proporciona el propi programa que és el solve_euler i he definit els paràmetres inicials.  Després he escrit la iteració que volia que seguís. Finalment he graficat la solució.
# Perquè fos un problema que no sapigui resoldre ò almenys que fos complicat, primer he resolt una Equació diferencial fàcil de la qual sé la resposta, per comprovar que està bé i, després una més complicada, que amb altres eines he comprovat també que dona un resultat esperat.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Definir equació diferencial
def f(x, y):
    return y

# Paràmetres inicials
x0, y0 = 0,1
h = 0.1  #Pas entre valors de x
n = 100  #Número de repeticions

# Euler per definir equació diferencial
def solve_euler(f, x0, y0, h, n):
    x_values = []
    y_values = []

    for i in range(n+1):        #Iteració que anirà de i=0 a i=n
        x0 = x0 + i * h         #Valor de x en cada cas.
        y0 = y0 + h * f(x0, y0) #Valor de y en cada cas

        x_values.append(x0)     #Crear llista de valors de x
        y_values.append(y0)     #Crear llista de valors de y

    return x_values, y_values

# Resoldre l'equació diferencial
x_values, y_values = solve_euler(f, x0, y0, h, n)

# Graficar la solución
plt.plot(x_values, y_values,)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Solució Equació diferencial')
plt.show()

# %% [markdown]
# Solució esperada

# %% [markdown]
# ![y.JPG](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir equació diferencial
def f(x, y):
    return y**2 - np.exp(-x) * np.sin(y)

# Paràmetres inicials
x0, y0 = 0.1, 0.1
h = 0.001 #Pas entre valors de x
n = 100   #Número de repeticions

# Euler per definir equació diferencial
def solve_euler(f, x0, y0, h, n):
    x_values = []
    y_values = []

    for i in range(n+1):        #Iteració que anirà de i=0 a i=n
        x0 = x0 + i * h         #Valor de x en cada cas
        y0 = y0 + h * f(x0, y0) #Valor de y en cada cas

        x_values.append(x0)     #Crear llista de valors de x
        y_values.append(y0)     #Crear llista de valors de y

    return x_values, y_values

# Resoldre l'equació diferencial
x_values, y_values = solve_euler(f, x0, y0, h, n)

# Graficar la solución
plt.plot(x_values, y_values,)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Solució Equació diferencial')
plt.show()

# %% [markdown]
# Solució esperada

# %% [markdown]
# ![image.png](data:image/png;base64,...)
